# %%
# Setup
result = 0
input_file = 'example_input_01_02.txt'

# %%
with open(input_file, 'r', encoding='utf-8') as input:
    for line in input:
        print(line)
# Out:
# two1nine
#
# eightwothree
#
# abcone2threexyz
#
# xtwone3four
#
# 4nineeightseven2
#
# zoneight234
#
# 7pqrstsixteen
